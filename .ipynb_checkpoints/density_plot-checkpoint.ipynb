# %% [markdown]
# # Retrieve Snow Denisties and Plot
#
# retrieve densitities within pits and plot against ? (grain size? hardness? depth?)

# %%
import pandas as pd

# %% [markdown]
# ## Retrieve Snow Denisties From SnowEx SQL Database

# %% [markdown]
# https://snowex-hackweek.github.io/website/tutorials/microstructure/microstructure-tutorial.html

# %%
# Modules needed to access snowexsql: SnowEx field data database
from snowexsql.db import get_db
from snowexsql.data import SiteData, PointData, LayerData, ImageData
from snowexsql.conversions import points_to_geopandas, query_to_geopandas

# Modules needed to work with data
import geoalchemy2.functions as gfunc
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

#note - this cell does not return any output

# %%
# Import the class reflecting the points table in the db
from snowexsql.data import SiteData

# Import the function to investigate a table
from snowexsql.db import get_table_attributes

# Use the function to see what columns are available to use. 
db_columns = get_table_attributes(SiteData)

# Print out the results nicely
print("These are the available columns in the table:\n \n* {}\n".format('\n* '.join(db_columns)))
# Out:
# These are the available columns in the table:
#
# * air_temp
# * aspect
# * date
# * date_accessed
# * doi
# * easting
# * elevation
# * geom
# * ground_condition
# * ground_roughness
# * ground_vegetation
# * latitude
# * longitude
# * metadata
# * northing
# * precip
# * site_id
# * site_name
# * site_notes
# * sky_cover
# * slope_angle
# * time
# * time_created
# * time_updated
# * total_depth
# * tree_canopy
# * utm_zone
# * vegetation_height
# * weather_description
# * wind

# %%
db_name = 'snow:hackweek@52.32.183.144/snowex'
engine, session = get_db(db_name)

# Grab all the equivalent diameter profiles
q = session.query(LayerData).filter(LayerData.type == 'density')
density_df = query_to_geopandas(q, engine)

# End our database session to avoid hanging transactions
session.close()

density_df.head() #check out the results of the query
# Out:
#     site_name        date                     time_created time_updated    id  \
# 0  Grand Mesa  2020-01-30 2021-06-01 18:41:20.949438+00:00         None  4272
# 1  Grand Mesa  2020-01-30 2021-06-01 18:41:20.951032+00:00         None  4273
# 2  Grand Mesa  2020-01-30 2021-06-01 18:41:20.952559+00:00         None  4274
# 3  Grand Mesa  2020-01-30 2021-06-01 18:41:20.953923+00:00         None  4275
# 4  Grand Mesa  2020-01-30 2021-06-01 18:41:20.955563+00:00         None  4276
#
#                                     doi date_accessed instrument     type  \
# 0  https://doi.org/10.5067/DUD2VZEVBJ7S    2021-05-30       None  density
# 1  https://doi.org/10.5067/DUD2VZEVBJ7S    2021-05-30       None  density
# 2  https://doi.org/10.5067/DUD2VZEVBJ7S    2021-05-30       None  density
# 3  https://doi.org/10.5067/DUD2VZEVBJ7S    2021-05-30       None  density
# 4  https://doi.org/10.5067/DUD2VZEVBJ7S    2021-05-30       None  density
#
#   units  ...                            geom            time  depth  site_id  \
# 0  None  ...  POINT (743040.000 4324967.000)  08:57:00-06:00   75.0     9C17
# 1  None  ...  POINT (743040.000 4324967.000)  08:57:00-06:00   65.0     9C17
# 2  None  ...  POINT (743040.000 4324967.000)  08:57:00-06:00   55.0     9C17
# 3  None  ...  POINT (743040.000 4324967.000)  08:57:00-06:00   45.0     9C17
# 4  None  ...  POINT (743040.000 4324967.000)  08:57:00-06:00   35.0     9C17
#
#    bottom_depth comments sample_a sample_b sample_c  value
# 0          65.0     None     None     None     None  124.5
# 1          55.0     None     None     None     None  207.0
# 2          45.0     None     None     None     None  230.0
# 3          35.0     None     None     None     None  258.5
# 4          25.0     None     None     None     None  258.0
#
# [5 rows x 27 columns]

# %%
density_df

# %%
db_name = 'snow:hackweek@52.32.183.144/snowex'
engine, session = get_db(db_name)

# Grab all the equivalent diameter profiles
q = session.query(SiteData)
siteData_df = query_to_geopandas(q, engine)

# End our database session to avoid hanging transactions
session.close()

siteData_df.head() #check out the results of the query
# Out:
#     site_name        date                     time_created time_updated  id  \
# 0  Grand Mesa  2020-02-01 2021-06-01 18:41:44.242179+00:00         None   1
# 1  Grand Mesa  2020-02-01 2021-06-01 18:41:44.249114+00:00         None   2
# 2  Grand Mesa  2020-02-01 2021-06-01 18:41:44.251987+00:00         None   3
# 3  Grand Mesa  2020-02-01 2021-06-01 18:41:44.254988+00:00         None   4
# 4  Grand Mesa  2020-02-01 2021-06-01 18:41:44.257945+00:00         None   5
#
#   site_id                                   doi date_accessed   latitude  \
# 0    5S21  https://doi.org/10.5067/DUD2VZEVBJ7S          None  39.019348
# 1    9S39  https://doi.org/10.5067/DUD2VZEVBJ7S          None  39.018431
# 2    2S37  https://doi.org/10.5067/DUD2VZEVBJ7S          None  39.019260
# 3    8N45  https://doi.org/10.5067/DUD2VZEVBJ7S          None  39.030896
# 4    6C34  https://doi.org/10.5067/DUD2VZEVBJ7S          None  39.012141
#
#     longitude  ...                                weather_description  precip  \
# 0 -108.175169  ...                                      Thin overcast    None
# 1 -108.155954  ...                                               None    None
# 2 -108.159282  ...           Overcast, 100% high cirrus - burning off    None
# 3 -108.151781  ...  High thin clouds - altocumulus. Some contrails...    None
# 4 -108.154798  ...                          Very warm out, t-shirt WX    None
#
#                   sky_cover   wind ground_condition ground_roughness  \
# 0  Overcast(complete cover)  Light           Frozen           Smooth
# 1                     Clear   Calm           Frozen            Rough
# 2  Overcast(complete cover)  Light           Frozen           Smooth
# 3     Broken (> 1/2 of sky)   Calm           Frozen           Smooth
# 4     Broken (> 1/2 of sky)   Calm           Frozen           Smooth
#
#    ground_vegetation  vegetation_height    tree_canopy  site_notes
# 0              Grass                 10       No Trees        None
# 1    Grass, Deadfall             10, 10  Open (20-70%)        None
# 2              Grass                 10       No Trees        None
# 3       Grass, Shrub             10, 30  Open (20-70%)        None
# 4       Grass, Shrub             10, 45       No Trees        None
#
# [5 rows x 30 columns]

# %%
merged_df = pd.merge(left=density_df, right=siteData_df, left_on='site_id', right_on='site_id')

# %%
df.drop(['B', 'C'], axis=1)
